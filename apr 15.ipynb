# %%
class laptop:
 def_init_(self,brand,price,ram,rom):
    self.brand=brand
    self.price=price
    self.ram=ram
    self.rom=rom
    print("Automatically calls")
def show(self)
    print("**********")
    print(f"Laptop brand{self.brand}")
    print(f"Laptop price{self.price}")
    print(f"Laptop ram{self.ram}")
    print(f"Laptop rom{self.rom}")
    print("**********")

L1=laptop("hp",67000,"64gb",120)
L2=laptop("lenova",70000,"84gb",130)
L3=laptop("dell",50000,"120gb",120)

L1.show()
L2.show()
# Out:
#   Cell In[3], line 2
#     def_init_(self,brand,price,ram,rom):
#                                        ^
# SyntaxError: invalid syntax

# %%
#inheritance ------------>one class inherit properties ,method from another class'
# why inheritancees 
    types of inheritances 
* single inheritances
* multiple inheritances
* multilevel inheritances
* hierchial inheritances
* hybrid inheritances

# %%
#single inheritance
class animal:
    def show(self):
    print("Animals....")

    class dog(animal):
        def sound I(sefl):
         print("Dogs make sound")
        def show(self):
            super().show()
            print("Dogs shows")
            animal.show(self)
# Out:
#   Cell In[6], line 4
#     print("Animals....")
#     ^
# IndentationError: expected an indented block after function definition on line 3

# %%
class grandparent:
    def work (self):
        print(f"Grandapa reading newspaper")
 class(grandparent):
         def
# Out:
#   File <string>:4
#     class(grandparent)
#                       ^
# IndentationError: unindent does not match any outer indentation level

# %%
#hierchical inheritance 

class parent:
     def show(self):
         print("parents.......")
class child(parents):
    pass 
class son(parent):
    pass
    
s1=son()
c1=chils()

s1.show()
c1.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       2
#       3 class parent:
#       4      def show(self):
#       5          print("parents.......")
# ----> 6 class child(parents):
#       7     pass
#       8 class son(parent):
#       9     pass
#
# NameError: name 'parents' is not defined

# %%
# encapsulation ---------->wrapping a data into sigle unit
why encapsulation ? 
    data securty 

acess modifiers:
    1 private 
    2 public
    3 protected

# %%
class employee:
  def  _init _(self , name, salary,job):
    self.name=name
    self.salary=salary
    self.job=job
