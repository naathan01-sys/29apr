# %%
number1=int(input("enter the number1"))
if number1%2==0:
    #print(number1,"is even)
    print(f"{number1}is even ")
else:
    print(f"{number1} is odd")
# Out:
# enter the number1 25
# 25 is odd

# %%
num=int(input("enter the number"))
if num<0:
            print("its negative ")
elif num(2==0):
            print("zero")      
else:
            print("its positive")
# Out:
# enter the number 25
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       1 num=int(input("enter the number"))
#       2 if num<0:
#       3             print("its negative ")
# ----> 4 elif num(2==0):
#       5             print("zero")
#       6 else:
#       7             print("its positive")
#
# TypeError: 'int' object is not callable

# %%
marks=int(input("enter the marks (0-100)"))
if marks>=90 and marks<=100:
          print("Grade A")
elif marks>=80 and marks<=89: 
          print("Grade B")
elif marks>=70 and marks<=79:
           print("Grade c")
elif marks>=60 and marks<=69:
            print("Grade d")
elif marks<60:
        print("Grade e")
else:
    print("invalidmark")
# Out:
# enter the marks (0-100) 52
# Grade e

# %%
age=int(input("enter the age"))
if age<18:
    print("not eligible to vote")
elif age==18:
    print("waiting list")
else:
    print("eligible for vote")
# Out:
# enter the age 22
# eligible for vote

# %%
#write a python program to find the largest of two number entered by user

# %%
number=int(input("enter the number"))
a=92
b=20
if a>=b:
   print("it is bigger")
else:
    print("it is smaller")
# Out:
# enter the number 25
# it is bigger

# %%
number=int(input("enter  the number "))
if number

# %%
user_input=int(input("ebter the number"))
if user_input>0:
    if use_input%2==0:
        print(f"{user_input) is even")
    else:
        print(F"{user_input} is odd")
elif user_input<0:
    if abs(user_input)%5==0:
        print

# %%
username=input("enter the username")
password=input("enter the password")

if username=="admin" and password=="admin@123":
        print("login sucessfully")
elif username=="admin" and password!="admin123":
         print("Wrong password")
else:
         print("user not found")
# Out:
# enter the username admin
# enter the password add
# Wrong password

# %%
wid_amount=int(input("enter the withdrawl amount"))
 acc_bal=10000
 if wid_amount*100 and wid_amount<=acc_bal:
    print
else balance=acc_bal-wid_amount:
    print("balance")
# Out:
#   Cell In[47], line 2
#     acc_bal=10000
#     ^
# IndentationError: unexpected indent
