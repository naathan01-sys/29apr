# %%
Write a Python program that takes three numbers as input and prints the
smallest number.

# %%
a=5
b=3
c=1
if a<b:
    print("small")
elif: c<b:
    print("")
else:c<a
    print("smallest number")
# Out:
#   Cell In[5], line 6
#     elif: c<b:
#         ^
# SyntaxError: invalid syntax

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10,100):
print(i)
# Out:
#   Cell In[12], line 2
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
N=int(input())
sum=5
for i in range(N+1):
sum=sum+i
print(sum)
# Out:
#   Cell In[19], line 4
#     sum=sum+i:
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %%
number=
for i in range(num*5):
    number=num*5

# %%
table_no=int(input("enter the table no"))
for i in range(1,21):
 print(f"{table_no}x{i}={table_no}*{i}
# Out:
#   Cell In[37], line 3
#     print(f"{table_no}x{i}={table_no}*{i}
#           ^
# SyntaxError: unterminated f-string literal (detected at line 3)

# %%
i=0
while i<=5:
print(i)
    i=i+1
# Out:
#   Cell In[36], line 3
#     print(i)
#     ^
# IndentationError: expected an indented block after 'while' statement on line 2

# %%
##### password=input("enter the password")
correctpassword="admin@123"
while password!=correctpassword:
    print("wrongpassword,tryagain")
    password=input("enter the password")
print("access granted")
# Out:
# enter the password 116
# wrongpassword,tryagain
# enter the password wr
# access granted
# wrongpassword,tryagain
# enter the password frwffefec
# access granted
# wrongpassword,tryagain
# enter the password cdc
# access granted
# wrongpassword,tryagain
# enter the password werf
# access granted
# wrongpassword,tryagain
# enter the password gr
# access granted
# wrongpassword,tryagain
# enter the password l,
# access granted
# wrongpassword,tryagain
# enter the password 20
# access granted
# wrongpassword,tryagain
# enter the password ml
# access granted
# wrongpassword,tryagain
# enter the password admin@123
# access granted

# %%
row=5
for i in range(1,row+1):
    print('*'*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,10):  #break 
    if i==3:
        break
    print(i)
# Out:
# 1
# 2

# %%
for i in range(1,10):  #continue
    ifi==3:
     continue
print(i)
# Out:
#   Cell In[32], line 2
#     ifi==3:
#           ^
# SyntaxError: invalid syntax

# %%
for i in range(1,10): #pass  
    if i==3:
        pass
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
