# %%
a=10

# %%
a
# Out:
# 10

# %%
a=10
b=12
a=b
b=a
print(a)
print (b)
# Out:
# 12
# 12

# %% [markdown]
# x=10
# y=float(x)
# print(x)
# print(y)

# %%
x=10.7
y=int(x)
print(x)
print(y)
# Out:
# 10.7
# 10

# %%
num1=10
num2=5
print(num1+num2)
print(num1+num2)
# Out:
# 15

# %%
#data structures----->list,tuple ,set dictionary
#1.list 
1. we can store different datatypes 
2.duplicated can allowed 
3.mutable

# %%
#index 
1. positive 
2. negative 
3.,start sindex,stop index,step index

# %%
name=["anbu","nathan","alagu","ram","mohan","subash"]

# %%
name[0:4]
# Out:
# ['anbu', 'nathan', 'alagu', 'ram']

# %%
shoppingcart1=["toys","apple","banana","chart","board","cherry",["veggies",["carrot","beetroot","fruit"]]]

# %%
shoppingcart1[1:3]
# Out:
# ['apple', 'banana']

# %%
shoppingcart1[-7:-3]
# Out:
# ['toys', 'apple', 'banana', 'chart']

# %%
shoppingcart1=["toys","apple","banana","chart","board","cherry",["veggies",["carrot","beetroot","fruit"]]]

# %%
shoppingcart1[:3]
# Out:
# ['toys', 'apple', 'banana']

# %%
shoppingcart1=["toys","apple","banana","chart","board","cherry",["veggies",["carrot","beetroot","fruit"]]]

# %%
shoppingcart1[1:]
# Out:
# ['apple',
#  'banana',
#  'chart',
#  'board',
#  'cherry',
#  ['veggies', ['carrot', 'beetroot', 'fruit']]]

# %%
shoppingcart1[6][1][0]
# Out:
# 'carrot'

# %%
shoppingcart1[ : :-1]
# Out:
# [['veggies', ['carrot', 'beetroot', 'fruit']],
#  'cherry',
#  'board',
#  'chart',
#  'banana',
#  'apple',
#  'toys']

# %%
list1=[1,2,3,4,5,6,7,8]

# %%
fname=["apple","banana","cherry","pomegrate","guva"]

# %%
fname[ : :2]
# Out:
# ['apple', 'cherry', 'guva']

# %%
fruits=["apple","banana","orange","mango"]

# %%
fruits
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %%
fruits.append("apple")  #single use

# %%
fruits
# Out:
# ['apple', 'banana', 'orange', 'mango', ['banana'], 'bananas', 'apple']

# %%
fruits.insert(1,"anbu")

# %% [raw]
# fruits

# %%
fruits.pop(2)








9
# Out:
# 9

# %%
# clear-delete 
#copy=copy#
#count =total cou
pop=
reverse=data reverse
append= single 
extend =

sum
min
 max

# %%
fruits1=["apple","banana","cherry","guva","pomegranate","apple"]

# %% [raw]
# fruits1.append("jackfruit")
