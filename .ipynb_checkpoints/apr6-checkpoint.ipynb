# %%
s1={1,2,3}
s2={3,4,5}
s1.intersection(s2)
# Out:
# {3}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 4, 5}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5}

# %%
s1.issubset(s2)
# Out:
# False

# %%
s2.issubset(s1)
# Out:
# False

# %%
#dictionary ---------> store key ,value pairs ,its mutable ,keys must be unique but  values 
#can be duplicate ,{}

# %%
students={"name":"sri","age":20,"city":"coimbatore"}

# %%
type(students)
# Out:
# dict

# %%
d1=dict(name="priya",age=25)

# %% [markdown]
# d1

# %% [markdown]
# {'name':'priya

# %%
students["name"]="lakshmisri"

# %%
students
# Out:
# {'name': 'lakshmisri', 'course': 'ai'}

# %%
students["course"]="ai"

# %% [markdown]
# students

# %%
students.get("namee","not found")
# Out:
# 'not found'

# %%
students
# Out:
# {'name': 'lakshmisri', 'course': 'ai'}

# %%
students.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
students.values()
# Out:
# dict_values(['sri', 20, 'coimbatore'])

# %%
students.items()
# Out:
# dict_items([('name', 'sri'), ('age', 20), ('city', 'coimbatore')])

# %%
students.pop("age")
# Out:
# 20

# %%
students.popitem()
# Out:
# ('city', 'coimbatore')

# %%
del students["city"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 del students["city"]
#
# KeyError: 'city'

# %%
students
# Out:
# {'name': 'lakshmisri', 'course': 'ai'}

# %%
update =merge 2 dictionary in 1 
fromkey

# %%
list1-["name",'age","address"]
d1=dict.fromkeys(list1,"unknown")
d1
# Out:
#   Cell In[30], line 1
#     list1-["name",'age","address"]
#                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
key['a','b','c']
value=0
pair=dict.fromkeys(key,value)
pair
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 key['a','b','c']
#       2 value=0
#       3 pair=dict.fromkeys(key,value)
#       4 pair
#
# NameError: name 'key' is not defined

# %%
data={"name":"priya","nickname":"sri""age"=25,"city":"coimbatore"}
# Out:
#   Cell In[32], line 1
#     data={"name":"priya","nickname":"sri""age"=25,"city":"coimbatore"}
#                                               ^
# SyntaxError: invalid syntax

# %%
data.
