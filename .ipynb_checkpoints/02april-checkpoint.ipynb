# %%
fruits=["apple","banana","cherry","guva","pomegranate","apple"]

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'guva', 'pomegranate', 'apple']

# %%
fruits.append("watermelon")

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'guva', 'pomegranate', 'apple', 'watermelon']

# %%
fruits.sort() #ascending order

# %%
fruits
# Out:
# ['apple', 'apple', 'banana', 'cherry', 'guva', 'pomegranate', 'watermelon']

# %% [raw]
# fruits1=["apple","banana","cherry","guva","pomegranate","apple","0","2"]

# %%
fruits1
# Out:
# ['apple', 'banana', 'cherry', 'guva', 'pomegranate', 'apple']

# %%
fruits.sort(reverse=True)

# %%
fruits
# Out:
# ['watermelon', 'pomegranate', 'guva', 'cherry', 'banana', 'apple', 'apple']

# %%
fruits.index("guva")
# Out:
# 2

# %%
fru=fruits.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 fru=fruits.copy()
#
# NameError: name 'fruits' is not defined

# %%
fru
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 fru
#
# NameError: name 'fru' is not defined

# %%
fruits.clear()

# %% [raw]
# fruits

# %% [raw]
# fru.index("cherry")

# %%
fruit1=["apple","banana","cherry","guva","pomegranate","jack"]

# %%
fruit1
# Out:
# ['apple', 'banana', 'cherry', 'guva', 'pomegranate', 'jack']

# %% [raw]
# fruit1.count("cherry")

# %% [markdown]
# fruit1

# %%
fruit1.reverse()

# %%
fruit1
# Out:
# ['apple', 'banana', 'cherry', 'guva', 'pomegranate', 'jack']

# %%
fruit1
# Out:
# ['jack', 'pomegranate', 'guva', 'cherry', 'banana', 'apple']

# %%
a=["1","3","5","7","9"]

# %%
len(a)
# Out:
# 5

# %%
min(a)
# Out:
# '1'

# %%
max(a)
# Out:
# '9'

# %%
sum(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sum(a)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
t=["anbu ","alagu","mathan"]

# %%
t
# Out:
# ['anbu ', 'alagu', 'mathan']

# %%
t.remove("alagu")

# %%
t
# Out:
# ['anbu ', 'mathan']

# %%
t.remove("mathan")

# %%
t
# Out:
# ['anbu ']

# %%
y=["1","2","3","4","5"]

# %%
y
# Out:
# ['1', '2', '3', '4', '5']

# %%
y.remove("3")

# %%
y
# Out:
# ['1', '2', '4', '5']

# %%
tuple1=("apple","banana","cherry",["carrot","cherry","beetroot","gabbage"],["beetroot","nut"])

# %%
tuple1
# Out:
# ('apple',
#  'banana',
#  'cherry',
#  ['carrot', 'cherry', 'beetroot', 'gabbage'],
#  ['beetroot', 'nut'])

# %%
tuple1.count("cherry")
# Out:
# 1

# %%
t1=list(tuple1)

# %%
t1
# Out:
# ['apple', 'banana', 'cherry', ['carrot', 'beetroot', 'gabbage']]

# %%
tuple=("apple","cherry","banana","cherry",["carrot","cherry","beetroot","gabbage"],["beetroot","nut"])

# %%
tuple
# Out:
# ('apple',
#  'cherry',
#  'banana',
#  'cherry',
#  ['carrot', 'cherry', 'beetroot', 'gabbage'],
#  ['beetroot', 'nut'])

# %%
tuple.count("cherry")
# Out:
# 2

# %%
tuple.index("cherry")
# Out:
# 1

# %%
t1=list

# %%
#1. merge 2 list into 1 then sort list #2. count how many times appreiaces in list #3. remove element fro tupil #4. finf length of tupil

# %%
list1=("apple","mango","jack")

# %%
list1
# Out:
# ('apple', 'mango', 'jack')

# %%
list2=("anbu","ram","sekar")

# %%
list2
# Out:
# ('anbu', 'ram', 'sekar')

# %%
a=(list1+list2)

# %%
a
# Out:
# ('apple', 'mango', 'jack', 'anbu', 'ram', 'sekar')

# %%
a.sort(reverse=false)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 a.sort(reverse=false)
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
a
# Out:
# ('apple', 'mango', 'jack', 'anbu', 'ram', 'sekar')

# %%
a.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 a.len()
#
# AttributeError: 'tuple' object has no attribute 'len'

# %%
a.count("mango")
# Out:
# 1

# %%
set is partially mutable

# %%
# 06/04/2026

# %%
s1={}
intersection
symmetric diffrernce (intersection opp )
union
issubset (l to r)
issuperset (r to l)
intersection_update
# Out:
#   Cell In[1], line 3
#     symmetric diffrernce
#               ^
# SyntaxError: invalid syntax

# %%
s1=
