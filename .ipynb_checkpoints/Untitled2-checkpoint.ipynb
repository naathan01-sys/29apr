# %%
print("123456",end=" ")
# Out:
# 123456

# %%
print("python is awesome")
# Out:
# python is awesome

# %%
print("123456",end="")
# Out:
# 123456

# %%
print("this is ram")
# Out:
# this is ram

# %%
print("2+3",end='=')
print(2+3)
# Out:
# 2+3=5

# %%
print("123456",end="")
print("this is ram")
# Out:
# 123456this is ram

# %%
print("money")
# Out:
# money

# %%
print("ram"

# %%
print("'it's Hero Time!'-Ben 10")
# Out:
# 'it's Hero Time!'-Ben 10

# %%
print("'it's Hero Time!'\n\t\t-Ben 10")
# Out:
# 'it's Hero Time!'
# 		-Ben 10

# %%
print("hi","hi",sep='...',end='...')
print('hi')
# Out:
# hi...hi...hi

# %%
#print

'''print("ram")
'''
# Out:
# 'print("ram")\n'

# %%
#print 
"""
print("anbu")
"""
# Out:
# '\nprint("anbu")\n'

# %%
a=True
type(a)
# Out:
# bool
