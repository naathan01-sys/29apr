# %%
class shape:
    def.area(self):
        pass

class rectangle(shape):
    def_init_(self,length,width):
    self.length=length
    self.width=width
    defarea (self):
    returnself.length*self.width

class circle(shape):
    def_init_(self,radius):
    self.radius=radius

    def area(self)
     returnmath.pi*self.radius
        
class triangle(shape):
    def_init_(self,b,h):
    self.b=b
    self.h=h
 def area(self):
     return).5*self.b*self.h
# Out:
#   File <string>:23
#     def area(self):
#                    ^
# IndentationError: unindent does not match any outer indentation level

# %%
# expection handlling-------> toa void runtime error 
1. try
2.except
3.finally

# %%
try:
    a=int(input("enter the number"))
    #b=int(input("enter the number 2"))
    print(a)
# except  Exception as e :
# print(a)
except ValueError:
    print("The value should be in integer")
else:
    print("try block worked")
finally:
    print("executed")
# Out:
# enter the number 0
# 0
# try block worked
# executed

# %%
class agetosmall(Exception):
    pass

def checkage(age):
    if age<0:
        raise agetosmall("Age should be positive")
    else:
        print("Valid age ")

try:
    checkage(-9)
except Exception as e:
    print(e)
# Out:
# Age should be positive
