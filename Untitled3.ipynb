# %%
data=

# %%
# video 1

# %%
print(ram)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(ram)
#
# NameError: name 'ram' is not defined
